# %%
import os
import random 
import numpy as np
import tensorflow as tf
import random as python_random
import tensorflow_addons as tfa
import tensorflow.keras as keras
from PIL import Image

random_seed = 123456

np.random.seed(random_seed)
python_random.seed(random_seed)
tf.random.set_seed(random_seed)


import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"

import sys
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.layers import Flatten, Dense
import argparse
# Out:
# 2024-11-20 08:29:44.381549: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-20 08:29:44.427401: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-20 08:29:44.428231: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-20 08:29:45.224887: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
def split_dataset(goodware_dir, malware_dir, output_dir, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    # Ensure the ratios sum to 1
    assert train_ratio + val_ratio + test_ratio == 1.0, "Ratios must sum to 1"
    
    # Get lists of hashes
    goodware_hashes = ["goodware/" + f.split('.')[0] for f in os.listdir(goodware_dir) if f.endswith('.png')]
    malware_hashes = ["malware/" + f.split('.')[0] for f in os.listdir(malware_dir) if f.endswith('.png')]
    
    # Shuffle the hashes
    random.seed(42)  # For reproducibility
    random.shuffle(goodware_hashes)
    random.shuffle(malware_hashes)
    
    # Split goodware and malware
    def split_hashes(hashes, train_ratio, val_ratio):
        n = len(hashes)
        train_end = int(n * train_ratio)
        val_end = train_end + int(n * val_ratio)
        return hashes[:train_end], hashes[train_end:val_end], hashes[val_end:]
    
    goodware_train, goodware_val, goodware_test = split_hashes(goodware_hashes, train_ratio, val_ratio)
    malware_train, malware_val, malware_test = split_hashes(malware_hashes, train_ratio, val_ratio)
    
    # Combine goodware and malware for each split
    train_set = goodware_train + malware_train
    val_set = goodware_val + malware_val
    test_set = goodware_test + malware_test
    
    # Write to files
    os.makedirs(output_dir, exist_ok=True)
    for filename, data in zip(
        ['train.txt', 'validation.txt', 'test.txt'], 
        [train_set, val_set, test_set]
    ):
        with open(os.path.join(output_dir, filename), 'w') as f:
            f.write('\n'.join(data))
    
    # Print percentages
    total_samples = len(goodware_hashes) + len(malware_hashes)
    print("Training: {:.2f}%".format(len(train_set) / total_samples * 100))
    print("Validation: {:.2f}%".format(len(val_set) / total_samples * 100))
    print("Testing: {:.2f}%".format(len(test_set) / total_samples * 100))

# %%
goodware_dir = "/scratch/users/mbenali/download_apk/images/goodware"
malware_dir = "/scratch/users/mbenali/download_apk/images/malware"
output_dir = "/scratch/users/mbenali/DexRay/data_splits"

split_dataset(goodware_dir, malware_dir, output_dir)
# Out:
# Training: 70.00%
# Validation: 14.99%
# Testing: 15.01%

# %%
EPOCHS = 200
BATCH_SIZE = 10
IMG_SIZE = 128
PATH_FILES = "/scratch/users/mbenali/DexRay/data_splits"
IMG_SIZE = 128

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    if parts[-2] == "goodware":
        return [0]
    else:
        return [1]


def get_image(path_img):
    image = np.asarray(Image.open(path_img))
    image = tf.convert_to_tensor(image, dtype_hint=None, name=None)
    return image


def get_shape(image):
    return image.shape[0]


def decode_img(path_img):
    image = tf.numpy_function(get_image, [path_img], tf.uint8)
    shape = tf.numpy_function(get_shape, [image], tf.int64)
    image = tf.reshape(image, [shape, 1, 1])
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, [IMG_SIZE * IMG_SIZE, 1])
    return tf.reshape(image, [IMG_SIZE * IMG_SIZE, 1])


def process_path(file_path):
    label = get_label(file_path)
    img = decode_img(file_path)
    return img, label

def train_model(
    path_images, # path to directory containing images
    dir_name, # path where to save the model
    file_name, # results file
    EPOCHS,
    BATCH_SIZE,
    IMG_SIZE,
    PATH_FILES,
):
    recall_list, precision_list, accuracy_list, f1_list = [], [], [], []

    model_architecture = Sequential()
    model_architecture.add(
        Conv1D(
            filters=64,
            kernel_size=12,
            activation="relu",
            input_shape=(IMG_SIZE * IMG_SIZE, 1),
        )
    )
    model_architecture.add(MaxPooling1D(pool_size=12))
    model_architecture.add(Conv1D(filters=128, kernel_size=12, activation="relu"))
    model_architecture.add(MaxPooling1D(pool_size=12))
    model_architecture.add(Flatten())
    model_architecture.add(Dense(64, activation="sigmoid"))
    model_architecture.add(Dense(1, activation="sigmoid"))

    file_results = open(file_name, "w")
    file_results.write(
        "Scores of the performance evaluation are: Accuracy, Precision, Recall, F1-score\n"
    )


    file_results.write("Run:\n")
    print("Run:")
    with open(os.path.join(PATH_FILES, "train.txt")) as f:
        train_hashes = f.read().splitlines()
        train_imgs = [
            os.path.join(path_images, image_hash + ".png") for image_hash in train_hashes
        ]
    f.close()

    with open(os.path.join(PATH_FILES, "validation.txt")) as f:
        valid_hashes = f.read().splitlines()
        valid_imgs = [
            os.path.join(path_images, image_hash + ".png") for image_hash in valid_hashes
        ]
    f.close()

    with open(os.path.join(PATH_FILES, "test.txt")) as f:
        test_hashes = f.read().splitlines()
        test_imgs = [
            os.path.join(path_images, image_hash + ".png") for image_hash in test_hashes
        ]
    f.close()

    train_dataset = tf.data.Dataset.from_tensor_slices(train_imgs)
    train_dataset = train_dataset.map(
        process_path, num_parallel_calls=tf.data.experimental.AUTOTUNE
    )
    length_train = len(train_imgs)
    batch_train = length_train // BATCH_SIZE
    train_dataset = train_dataset.cache()
    train_dataset = train_dataset.shuffle(
        buffer_size=length_train, seed=random_seed, reshuffle_each_iteration=False
    )
    train_dataset = train_dataset.batch(batch_train)
    train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)

    valid_dataset = tf.data.Dataset.from_tensor_slices(valid_imgs)
    valid_dataset = valid_dataset.map(
        process_path, num_parallel_calls=tf.data.experimental.AUTOTUNE
    )
    length_valid = len(valid_imgs)
    batch_valid = length_valid // BATCH_SIZE
    valid_dataset = valid_dataset.cache()
    valid_dataset = valid_dataset.shuffle(
        buffer_size=length_valid, seed=random_seed, reshuffle_each_iteration=False
    )
    valid_dataset = valid_dataset.batch(batch_valid)
    valid_dataset = valid_dataset.prefetch(tf.data.experimental.AUTOTUNE)

    test_dataset = tf.data.Dataset.from_tensor_slices(test_imgs)
    test_dataset = test_dataset.map(
        process_path, num_parallel_calls=tf.data.experimental.AUTOTUNE
    )
    length_test = len(test_imgs)
    batch_test = length_test // BATCH_SIZE
    test_dataset = test_dataset.cache()
    test_dataset = test_dataset.shuffle(
        buffer_size=length_test, seed=random_seed, reshuffle_each_iteration=False
    )
    test_dataset = test_dataset.batch(batch_test)
    test_dataset = test_dataset.prefetch(tf.data.experimental.AUTOTUNE)

    model = keras.models.clone_model(model_architecture)
    model.compile(
        optimizer="adam",
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=[
            "accuracy",
            tf.keras.metrics.Precision(),
            tf.keras.metrics.Recall(),
            tfa.metrics.F1Score(num_classes=2, average="micro", threshold=0.5),
        ],
    )

    es_callback = tf.keras.callbacks.EarlyStopping(
        monitor="val_accuracy", patience=50, restore_best_weights=True
    )
    cp_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(dir_name, "cp"),
        save_weights_only=True,
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
    )
    path_save_model = os.path.join(dir_name, "model")

    model.fit(
        train_dataset,
        shuffle=True,
        validation_data=valid_dataset,
        epochs=EPOCHS,
        callbacks=[es_callback, cp_callback],
        verbose=2,
    )
    model.save(path_save_model)
    print("Evaluate the model")
    evaluation_scores = model.evaluate(test_dataset, verbose=2)
    file_results.write("%s  \n" % evaluation_scores[1:])
    file_results.write("#" * 50 + "\n")
    accuracy_list.append(evaluation_scores[1])
    precision_list.append(evaluation_scores[2])
    recall_list.append(evaluation_scores[3])
    f1_list.append(evaluation_scores[4])
    
    
    file_results.write(
        "Average scores: %f %f %f %f"
        % (
            np.mean(accuracy_list),
            np.mean(precision_list),
            np.mean(recall_list),
            np.mean(f1_list),
        )
    )

    file_results.close()

# %%
train_model(
    "/scratch/users/mbenali/download_apk/images", 
    'model', 
    '/scratch/users/mbenali/DexRay/results/scores.txt', 
    EPOCHS, 
    BATCH_SIZE, 
    IMG_SIZE, 
    '/scratch/users/mbenali/DexRay/data_splits' 
)
# Out:
# Run:
# Epoch 1/200
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (93717204 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:35:33.122797: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 40 of 7613
# 2024-11-20 08:35:44.334910: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 99 of 7613
# 2024-11-20 08:35:50.683722: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 146 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (95513412 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:36:02.279286: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 197 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (98497372 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:36:10.822636: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 243 of 7613
# 2024-11-20 08:36:21.643453: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 312 of 7613
# 2024-11-20 08:36:31.652002: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 357 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (92081648 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:36:41.148770: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 418 of 7613
# 2024-11-20 08:36:50.664561: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 471 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (134580948 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:37:01.793034: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 503 of 7613
# 2024-11-20 08:37:13.259178: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 551 of 7613
# 2024-11-20 08:37:21.787394: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 609 of 7613
# 2024-11-20 08:37:31.243956: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 649 of 7613
# 2024-11-20 08:37:42.106310: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 698 of 7613
# 2024-11-20 08:37:52.554589: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 766 of 7613
# 2024-11-20 08:38:01.029822: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 826 of 7613
# 2024-11-20 08:38:11.935384: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 887 of 7613
# 2024-11-20 08:38:20.968805: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 936 of 7613
# 2024-11-20 08:38:31.333220: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 975 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (158599980 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:38:44.480980: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1019 of 7613
# 2024-11-20 08:38:50.876220: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1050 of 7613
# 2024-11-20 08:39:01.651036: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1117 of 7613
# 2024-11-20 08:39:10.677562: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1194 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (150969820 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:39:22.005388: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1222 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (154020532 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:39:37.003793: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1289 of 7613
# 2024-11-20 08:39:40.769099: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1318 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (154872632 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:39:52.744596: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1334 of 7613
# 2024-11-20 08:40:03.404882: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1398 of 7613
# 2024-11-20 08:40:11.410572: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1452 of 7613
# 2024-11-20 08:40:21.028800: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1505 of 7613
# 2024-11-20 08:40:30.704349: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1544 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (97030596 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:40:41.246222: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1600 of 7613
# 2024-11-20 08:40:51.440596: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1629 of 7613
# 2024-11-20 08:41:02.109149: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1733 of 7613
# 2024-11-20 08:41:11.434915: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1772 of 7613
# 2024-11-20 08:41:22.473540: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1821 of 7613
# 2024-11-20 08:41:32.506489: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1870 of 7613
# 2024-11-20 08:41:42.353902: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1909 of 7613
# 2024-11-20 08:41:50.910850: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1991 of 7613
# 2024-11-20 08:42:02.424208: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2026 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (161408244 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:42:14.868756: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2070 of 7613
# 2024-11-20 08:42:21.519633: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2118 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (155978264 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:42:38.166860: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2166 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (124021352 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:42:46.199671: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2190 of 7613
# 2024-11-20 08:42:51.923402: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2229 of 7613
# 2024-11-20 08:43:02.127166: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2279 of 7613
# 2024-11-20 08:43:10.976290: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2345 of 7613
# 2024-11-20 08:43:20.695117: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2439 of 7613
# 2024-11-20 08:43:30.917680: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2509 of 7613
# 2024-11-20 08:43:41.324591: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2556 of 7613
# 2024-11-20 08:43:51.101364: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2629 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (170122652 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:44:02.313720: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2695 of 7613
# 2024-11-20 08:44:10.867617: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2705 of 7613
# 2024-11-20 08:44:20.770171: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2733 of 7613
# 2024-11-20 08:44:32.305167: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2806 of 7613
# 2024-11-20 08:44:41.891248: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2844 of 7613
# 2024-11-20 08:44:51.294038: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2902 of 7613
# 2024-11-20 08:45:01.391293: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2983 of 7613
# 2024-11-20 08:45:10.947735: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3034 of 7613
# 2024-11-20 08:45:21.600271: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3115 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (90457052 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:45:30.828782: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3191 of 7613
# 2024-11-20 08:45:41.077627: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3232 of 7613
# 2024-11-20 08:45:53.102859: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3304 of 7613
# 2024-11-20 08:46:00.953031: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3343 of 7613
# 2024-11-20 08:46:11.397207: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3421 of 7613
# 2024-11-20 08:46:21.145257: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3485 of 7613
# 2024-11-20 08:46:32.039620: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3546 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (91992828 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:46:43.655792: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3593 of 7613
# 2024-11-20 08:46:50.931714: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3633 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (110900284 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:47:02.800071: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3658 of 7613
# 2024-11-20 08:47:10.820285: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3705 of 7613
# 2024-11-20 08:47:23.267551: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3772 of 7613
# 2024-11-20 08:47:33.246027: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3825 of 7613
# 2024-11-20 08:47:41.476286: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3878 of 7613
# 2024-11-20 08:47:51.176628: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3928 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (89755024 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:48:02.176723: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 3980 of 7613
# 2024-11-20 08:48:11.437070: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4033 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (92394424 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:48:23.026414: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4100 of 7613
# 2024-11-20 08:48:34.148709: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4148 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (121557476 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:48:41.746375: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4162 of 7613
# 2024-11-20 08:48:50.704823: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4214 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (95707196 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:49:04.227295: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4259 of 7613
# 2024-11-20 08:49:10.758755: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4294 of 7613
# 2024-11-20 08:49:20.882613: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4378 of 7613
# 2024-11-20 08:49:31.609864: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4447 of 7613
# 2024-11-20 08:49:41.551906: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4505 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (101538428 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:49:55.415280: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4562 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (92886996 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:50:01.965999: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4581 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (92810800 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:50:12.170783: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4620 of 7613
# 2024-11-20 08:50:20.803235: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4688 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (123150752 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:50:31.175193: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4717 of 7613
# 2024-11-20 08:50:41.208713: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4787 of 7613
# 2024-11-20 08:50:50.821381: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4846 of 7613
# 2024-11-20 08:51:01.112125: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4900 of 7613
# 2024-11-20 08:51:11.119369: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4961 of 7613
# 2024-11-20 08:51:21.037465: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5005 of 7613
# 2024-11-20 08:51:30.701767: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5067 of 7613
# 2024-11-20 08:51:41.234040: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5135 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (118077688 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:51:53.841567: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5187 of 7613
# 2024-11-20 08:52:01.378794: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5252 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (123687532 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:52:10.818095: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5277 of 7613
# 2024-11-20 08:52:22.383582: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5339 of 7613
# 2024-11-20 08:52:32.068162: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5405 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (101293044 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:52:41.665190: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5450 of 7613
# 2024-11-20 08:52:51.946986: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5502 of 7613
# 2024-11-20 08:53:01.466984: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5556 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (162571280 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:53:15.608536: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5603 of 7613
# 2024-11-20 08:53:20.924130: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5634 of 7613
# 2024-11-20 08:53:31.340357: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5709 of 7613
# 2024-11-20 08:53:41.294560: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5751 of 7613
# 2024-11-20 08:53:51.444208: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5796 of 7613
# 2024-11-20 08:54:01.673501: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5853 of 7613
# 2024-11-20 08:54:10.889478: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5915 of 7613
# 2024-11-20 08:54:21.253037: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5969 of 7613
# 2024-11-20 08:54:33.457099: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6041 of 7613
# 2024-11-20 08:54:40.885125: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6086 of 7613
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (101934068 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 08:54:51.349085: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6127 of 7613
# 2024-11-20 08:55:02.668773: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6217 of 7613
# 2024-11-20 08:55:10.955312: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6284 of 7613
# 2024-11-20 08:55:21.516123: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6350 of 7613
# 2024-11-20 08:55:30.680310: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6420 of 7613
# 2024-11-20 08:55:41.182287: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6484 of 7613
# 2024-11-20 08:55:51.023405: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6565 of 7613
# 2024-11-20 08:56:04.566934: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6642 of 7613
# 2024-11-20 08:56:10.728637: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6691 of 7613
# 2024-11-20 08:56:21.787079: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6753 of 7613
# 2024-11-20 08:56:30.659604: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6829 of 7613
# 2024-11-20 08:56:40.812252: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6876 of 7613
# 2024-11-20 08:56:51.056277: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 6948 of 7613
# 2024-11-20 08:57:01.764173: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 7043 of 7613
# 2024-11-20 08:57:10.745615: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 7083 of 7613
# 2024-11-20 08:57:20.705421: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 7154 of 7613
# 2024-11-20 08:57:31.840911: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 7243 of 7613
# 2024-11-20 08:57:42.133278: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 7316 of 7613
# 2024-11-20 08:57:50.957019: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 7390 of 7613
# 2024-11-20 08:58:00.761825: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 7475 of 7613
# 2024-11-20 08:58:10.777226: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 7560 of 7613
# 2024-11-20 08:58:16.241236: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] Shuffle buffer filled.
# 2024-11-20 08:59:01.208216: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 82 of 1630
# 2024-11-20 08:59:11.712099: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 162 of 1630
# 2024-11-20 08:59:22.456531: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 197 of 1630
# 2024-11-20 08:59:30.193484: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 246 of 1630
# 2024-11-20 08:59:41.427021: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 314 of 1630
# 2024-11-20 08:59:50.587154: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 355 of 1630
# 2024-11-20 09:00:00.169277: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 452 of 1630
# 2024-11-20 09:00:10.524630: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 476 of 1630
# 2024-11-20 09:00:20.215759: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 512 of 1630
# 2024-11-20 09:00:30.141777: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 597 of 1630
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (162332224 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (122600384 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 09:00:44.372995: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 654 of 1630
# 2024-11-20 09:00:50.847097: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 677 of 1630
# 2024-11-20 09:01:00.232614: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 738 of 1630
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (103885756 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 09:01:10.804427: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 806 of 1630
# 2024-11-20 09:01:22.504359: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 834 of 1630
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (107845996 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 09:01:32.979850: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 889 of 1630
# 2024-11-20 09:01:41.704467: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 958 of 1630
# 2024-11-20 09:01:53.153330: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1017 of 1630
# 2024-11-20 09:02:00.408710: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1068 of 1630
# 2024-11-20 09:02:10.265301: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1124 of 1630
# 2024-11-20 09:02:20.357252: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1182 of 1630
# 2024-11-20 09:02:31.263355: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1282 of 1630
# 2024-11-20 09:02:42.542679: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1329 of 1630
# 2024-11-20 09:02:51.008780: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1372 of 1630
# 2024-11-20 09:03:00.508802: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1431 of 1630
# 2024-11-20 09:03:10.821888: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1499 of 1630
# 2024-11-20 09:03:20.597031: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1575 of 1630
# 2024-11-20 09:03:27.685061: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] Shuffle buffer filled.
# 11/11 - 1690s - loss: 0.5080 - accuracy: 0.8048 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.4952 - val_accuracy: 0.8049 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_f1_score: 0.0000e+00 - 1690s/epoch - 154s/step
# Epoch 2/200
# 11/11 - 36s - loss: 0.4787 - accuracy: 0.8048 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.4858 - val_accuracy: 0.8049 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_f1_score: 0.0000e+00 - 36s/epoch - 3s/step
# Epoch 3/200
# 11/11 - 36s - loss: 0.4598 - accuracy: 0.8183 - precision_2: 0.7004 - recall_2: 0.1211 - f1_score: 0.2065 - val_loss: 0.4818 - val_accuracy: 0.8110 - val_precision_2: 1.0000 - val_recall_2: 0.0314 - val_f1_score: 0.0610 - 36s/epoch - 3s/step
# Epoch 4/200
# 11/11 - 36s - loss: 0.4581 - accuracy: 0.8248 - precision_2: 0.9524 - recall_2: 0.1077 - f1_score: 0.1935 - val_loss: 0.4429 - val_accuracy: 0.8221 - val_precision_2: 0.9118 - val_recall_2: 0.0975 - val_f1_score: 0.1761 - 36s/epoch - 3s/step
# Epoch 5/200
# 11/11 - 36s - loss: 0.4451 - accuracy: 0.8304 - precision_2: 0.8397 - recall_2: 0.1622 - f1_score: 0.2719 - val_loss: 0.4305 - val_accuracy: 0.8368 - val_precision_2: 0.9194 - val_recall_2: 0.1792 - val_f1_score: 0.3000 - 36s/epoch - 3s/step
# Epoch 6/200
# 11/11 - 36s - loss: 0.4259 - accuracy: 0.8425 - precision_2: 0.9309 - recall_2: 0.2086 - f1_score: 0.3408 - val_loss: 0.4255 - val_accuracy: 0.8374 - val_precision_2: 0.9344 - val_recall_2: 0.1792 - val_f1_score: 0.3008 - 36s/epoch - 3s/step
# Epoch 7/200
# 11/11 - 36s - loss: 0.4176 - accuracy: 0.8476 - precision_2: 0.9116 - recall_2: 0.2429 - f1_score: 0.3836 - val_loss: 0.4293 - val_accuracy: 0.8380 - val_precision_2: 0.9355 - val_recall_2: 0.1824 - val_f1_score: 0.3053 - 36s/epoch - 3s/step
# Epoch 8/200
# 11/11 - 36s - loss: 0.4153 - accuracy: 0.8479 - precision_2: 0.8905 - recall_2: 0.2517 - f1_score: 0.3924 - val_loss: 0.4536 - val_accuracy: 0.8356 - val_precision_2: 0.9310 - val_recall_2: 0.1698 - val_f1_score: 0.2872 - 36s/epoch - 3s/step
# Epoch 9/200
# 11/11 - 36s - loss: 0.4136 - accuracy: 0.8507 - precision_2: 0.9106 - recall_2: 0.2604 - f1_score: 0.4050 - val_loss: 0.4259 - val_accuracy: 0.8442 - val_precision_2: 0.9444 - val_recall_2: 0.2138 - val_f1_score: 0.3487 - 36s/epoch - 3s/step
# Epoch 10/200
# 11/11 - 36s - loss: 0.4074 - accuracy: 0.8529 - precision_2: 0.8910 - recall_2: 0.2806 - f1_score: 0.4268 - val_loss: 0.4308 - val_accuracy: 0.8454 - val_precision_2: 0.9342 - val_recall_2: 0.2233 - val_f1_score: 0.3604 - 36s/epoch - 3s/step
# Epoch 11/200
# 11/11 - 36s - loss: 0.4010 - accuracy: 0.8549 - precision_2: 0.9187 - recall_2: 0.2813 - f1_score: 0.4307 - val_loss: 0.4136 - val_accuracy: 0.8472 - val_precision_2: 0.9157 - val_recall_2: 0.2390 - val_f1_score: 0.3791 - 36s/epoch - 3s/step
# Epoch 12/200
# 11/11 - 36s - loss: 0.3969 - accuracy: 0.8549 - precision_2: 0.8833 - recall_2: 0.2954 - f1_score: 0.4428 - val_loss: 0.4183 - val_accuracy: 0.8479 - val_precision_2: 0.9268 - val_recall_2: 0.2390 - val_f1_score: 0.3800 - 36s/epoch - 3s/step
# Epoch 13/200
# 11/11 - 36s - loss: 0.3938 - accuracy: 0.8560 - precision_2: 0.8980 - recall_2: 0.2961 - f1_score: 0.4453 - val_loss: 0.4118 - val_accuracy: 0.8509 - val_precision_2: 0.9213 - val_recall_2: 0.2579 - val_f1_score: 0.4029 - 36s/epoch - 3s/step
# Epoch 14/200
# 11/11 - 36s - loss: 0.3896 - accuracy: 0.8562 - precision_2: 0.8668 - recall_2: 0.3109 - f1_score: 0.4577 - val_loss: 0.4118 - val_accuracy: 0.8515 - val_precision_2: 0.9318 - val_recall_2: 0.2579 - val_f1_score: 0.4039 - 36s/epoch - 3s/step
# Epoch 15/200
# 11/11 - 36s - loss: 0.3890 - accuracy: 0.8564 - precision_2: 0.8816 - recall_2: 0.3055 - f1_score: 0.4538 - val_loss: 0.4080 - val_accuracy: 0.8509 - val_precision_2: 0.9121 - val_recall_2: 0.2610 - val_f1_score: 0.4059 - 36s/epoch - 3s/step
# Epoch 16/200
# 11/11 - 36s - loss: 0.3836 - accuracy: 0.8576 - precision_2: 0.8851 - recall_2: 0.3109 - f1_score: 0.4602 - val_loss: 0.4090 - val_accuracy: 0.8521 - val_precision_2: 0.9326 - val_recall_2: 0.2610 - val_f1_score: 0.4079 - 36s/epoch - 3s/step
# Epoch 17/200
# 11/11 - 36s - loss: 0.3818 - accuracy: 0.8577 - precision_2: 0.8795 - recall_2: 0.3143 - f1_score: 0.4631 - val_loss: 0.4068 - val_accuracy: 0.8509 - val_precision_2: 0.9121 - val_recall_2: 0.2610 - val_f1_score: 0.4059 - 36s/epoch - 3s/step
# Epoch 18/200
# 11/11 - 36s - loss: 0.3788 - accuracy: 0.8585 - precision_2: 0.8645 - recall_2: 0.3264 - f1_score: 0.4739 - val_loss: 0.4078 - val_accuracy: 0.8515 - val_precision_2: 0.9222 - val_recall_2: 0.2610 - val_f1_score: 0.4069 - 36s/epoch - 3s/step
# Epoch 19/200
# 11/11 - 36s - loss: 0.3763 - accuracy: 0.8587 - precision_2: 0.8825 - recall_2: 0.3183 - f1_score: 0.4679 - val_loss: 0.4025 - val_accuracy: 0.8503 - val_precision_2: 0.8936 - val_recall_2: 0.2642 - val_f1_score: 0.4078 - 36s/epoch - 3s/step
# Epoch 20/200
# 11/11 - 36s - loss: 0.3716 - accuracy: 0.8596 - precision_2: 0.8730 - recall_2: 0.3284 - f1_score: 0.4773 - val_loss: 0.4045 - val_accuracy: 0.8515 - val_precision_2: 0.9130 - val_recall_2: 0.2642 - val_f1_score: 0.4098 - 36s/epoch - 3s/step
# Epoch 21/200
# 11/11 - 36s - loss: 0.3693 - accuracy: 0.8598 - precision_2: 0.8708 - recall_2: 0.3311 - f1_score: 0.4798 - val_loss: 0.4042 - val_accuracy: 0.8509 - val_precision_2: 0.9032 - val_recall_2: 0.2642 - val_f1_score: 0.4088 - 36s/epoch - 3s/step
# Epoch 22/200
# 11/11 - 36s - loss: 0.3653 - accuracy: 0.8629 - precision_2: 0.8759 - recall_2: 0.3466 - f1_score: 0.4966 - val_loss: 0.4067 - val_accuracy: 0.8515 - val_precision_2: 0.9130 - val_recall_2: 0.2642 - val_f1_score: 0.4098 - 36s/epoch - 3s/step
# Epoch 23/200
# 11/11 - 36s - loss: 0.3635 - accuracy: 0.8621 - precision_2: 0.8695 - recall_2: 0.3452 - f1_score: 0.4942 - val_loss: 0.4069 - val_accuracy: 0.8515 - val_precision_2: 0.9130 - val_recall_2: 0.2642 - val_f1_score: 0.4098 - 36s/epoch - 3s/step
# Epoch 24/200
# 11/11 - 36s - loss: 0.3612 - accuracy: 0.8630 - precision_2: 0.8686 - recall_2: 0.3513 - f1_score: 0.5002 - val_loss: 0.4031 - val_accuracy: 0.8509 - val_precision_2: 0.9032 - val_recall_2: 0.2642 - val_f1_score: 0.4088 - 36s/epoch - 3s/step
# Epoch 25/200
# 11/11 - 37s - loss: 0.3587 - accuracy: 0.8635 - precision_2: 0.8719 - recall_2: 0.3526 - f1_score: 0.5022 - val_loss: 0.3995 - val_accuracy: 0.8528 - val_precision_2: 0.8980 - val_recall_2: 0.2767 - val_f1_score: 0.4231 - 37s/epoch - 3s/step
# Epoch 26/200
# 11/11 - 37s - loss: 0.3541 - accuracy: 0.8648 - precision_2: 0.8728 - recall_2: 0.3600 - f1_score: 0.5098 - val_loss: 0.3945 - val_accuracy: 0.8540 - val_precision_2: 0.9000 - val_recall_2: 0.2830 - val_f1_score: 0.4306 - 37s/epoch - 3s/step
# Epoch 27/200
# 11/11 - 37s - loss: 0.3494 - accuracy: 0.8665 - precision_2: 0.8815 - recall_2: 0.3654 - f1_score: 0.5167 - val_loss: 0.3975 - val_accuracy: 0.8528 - val_precision_2: 0.8750 - val_recall_2: 0.2862 - val_f1_score: 0.4313 - 37s/epoch - 3s/step
# Epoch 28/200
# 11/11 - 37s - loss: 0.3448 - accuracy: 0.8676 - precision_2: 0.8723 - recall_2: 0.3769 - f1_score: 0.5263 - val_loss: 0.3976 - val_accuracy: 0.8534 - val_precision_2: 0.8911 - val_recall_2: 0.2830 - val_f1_score: 0.4296 - 37s/epoch - 3s/step
# Epoch 29/200
# 11/11 - 37s - loss: 0.3413 - accuracy: 0.8689 - precision_2: 0.8765 - recall_2: 0.3822 - f1_score: 0.5323 - val_loss: 0.4025 - val_accuracy: 0.8534 - val_precision_2: 0.8911 - val_recall_2: 0.2830 - val_f1_score: 0.4296 - 37s/epoch - 3s/step
# Epoch 30/200
# 11/11 - 37s - loss: 0.3381 - accuracy: 0.8686 - precision_2: 0.8595 - recall_2: 0.3910 - f1_score: 0.5375 - val_loss: 0.4036 - val_accuracy: 0.8534 - val_precision_2: 0.8911 - val_recall_2: 0.2830 - val_f1_score: 0.4296 - 37s/epoch - 3s/step
# Epoch 31/200
# 11/11 - 37s - loss: 0.3361 - accuracy: 0.8702 - precision_2: 0.8609 - recall_2: 0.3997 - f1_score: 0.5460 - val_loss: 0.4046 - val_accuracy: 0.8540 - val_precision_2: 0.8922 - val_recall_2: 0.2862 - val_f1_score: 0.4333 - 37s/epoch - 3s/step
# Epoch 32/200
# 11/11 - 37s - loss: 0.3319 - accuracy: 0.8726 - precision_2: 0.8728 - recall_2: 0.4065 - f1_score: 0.5546 - val_loss: 0.3998 - val_accuracy: 0.8540 - val_precision_2: 0.8774 - val_recall_2: 0.2925 - val_f1_score: 0.4387 - 37s/epoch - 3s/step
# Epoch 33/200
# 11/11 - 37s - loss: 0.3268 - accuracy: 0.8726 - precision_2: 0.8583 - recall_2: 0.4159 - f1_score: 0.5603 - val_loss: 0.4050 - val_accuracy: 0.8571 - val_precision_2: 0.8972 - val_recall_2: 0.3019 - val_f1_score: 0.4518 - 37s/epoch - 3s/step
# Epoch 34/200
# 11/11 - 37s - loss: 0.3237 - accuracy: 0.8747 - precision_2: 0.8654 - recall_2: 0.4240 - f1_score: 0.5691 - val_loss: 0.4061 - val_accuracy: 0.8564 - val_precision_2: 0.8962 - val_recall_2: 0.2987 - val_f1_score: 0.4481 - 37s/epoch - 3s/step
# Epoch 35/200
# 11/11 - 37s - loss: 0.3203 - accuracy: 0.8772 - precision_2: 0.8698 - recall_2: 0.4361 - f1_score: 0.5809 - val_loss: 0.4040 - val_accuracy: 0.8564 - val_precision_2: 0.8889 - val_recall_2: 0.3019 - val_f1_score: 0.4507 - 37s/epoch - 3s/step
# Epoch 36/200
# 11/11 - 37s - loss: 0.3150 - accuracy: 0.8786 - precision_2: 0.8630 - recall_2: 0.4495 - f1_score: 0.5912 - val_loss: 0.4031 - val_accuracy: 0.8564 - val_precision_2: 0.8818 - val_recall_2: 0.3050 - val_f1_score: 0.4533 - 37s/epoch - 3s/step
# Epoch 37/200
# 11/11 - 37s - loss: 0.3103 - accuracy: 0.8793 - precision_2: 0.8658 - recall_2: 0.4515 - f1_score: 0.5935 - val_loss: 0.4105 - val_accuracy: 0.8540 - val_precision_2: 0.8390 - val_recall_2: 0.3113 - val_f1_score: 0.4541 - 37s/epoch - 3s/step
# Epoch 38/200
# 11/11 - 37s - loss: 0.3057 - accuracy: 0.8803 - precision_2: 0.8589 - recall_2: 0.4630 - f1_score: 0.6017 - val_loss: 0.4111 - val_accuracy: 0.8558 - val_precision_2: 0.8547 - val_recall_2: 0.3145 - val_f1_score: 0.4598 - 37s/epoch - 3s/step
# Epoch 39/200
# 11/11 - 37s - loss: 0.3014 - accuracy: 0.8831 - precision_2: 0.8670 - recall_2: 0.4738 - f1_score: 0.6127 - val_loss: 0.4095 - val_accuracy: 0.8564 - val_precision_2: 0.8684 - val_recall_2: 0.3113 - val_f1_score: 0.4583 - 37s/epoch - 3s/step
# Epoch 40/200
# 11/11 - 37s - loss: 0.2963 - accuracy: 0.8847 - precision_2: 0.8707 - recall_2: 0.4805 - f1_score: 0.6193 - val_loss: 0.4103 - val_accuracy: 0.8546 - val_precision_2: 0.8403 - val_recall_2: 0.3145 - val_f1_score: 0.4577 - 37s/epoch - 3s/step
# Epoch 41/200
# 11/11 - 37s - loss: 0.2913 - accuracy: 0.8862 - precision_2: 0.8717 - recall_2: 0.4892 - f1_score: 0.6267 - val_loss: 0.4087 - val_accuracy: 0.8534 - val_precision_2: 0.8319 - val_recall_2: 0.3113 - val_f1_score: 0.4531 - 37s/epoch - 3s/step
# Epoch 42/200
# 11/11 - 37s - loss: 0.2856 - accuracy: 0.8883 - precision_2: 0.8750 - recall_2: 0.4993 - f1_score: 0.6358 - val_loss: 0.4142 - val_accuracy: 0.8540 - val_precision_2: 0.8279 - val_recall_2: 0.3176 - val_f1_score: 0.4591 - 37s/epoch - 3s/step
# Epoch 43/200
# 11/11 - 37s - loss: 0.2814 - accuracy: 0.8911 - precision_2: 0.8763 - recall_2: 0.5148 - f1_score: 0.6486 - val_loss: 0.4173 - val_accuracy: 0.8503 - val_precision_2: 0.7891 - val_recall_2: 0.3176 - val_f1_score: 0.4529 - 37s/epoch - 3s/step
# Epoch 44/200
# 11/11 - 36s - loss: 0.2750 - accuracy: 0.8943 - precision_2: 0.8804 - recall_2: 0.5303 - f1_score: 0.6619 - val_loss: 0.4176 - val_accuracy: 0.8515 - val_precision_2: 0.8065 - val_recall_2: 0.3145 - val_f1_score: 0.4525 - 36s/epoch - 3s/step
# Epoch 45/200
# 11/11 - 37s - loss: 0.2701 - accuracy: 0.8966 - precision_2: 0.8888 - recall_2: 0.5377 - f1_score: 0.6700 - val_loss: 0.4146 - val_accuracy: 0.8528 - val_precision_2: 0.8145 - val_recall_2: 0.3176 - val_f1_score: 0.4570 - 37s/epoch - 3s/step
# Epoch 46/200
# 11/11 - 37s - loss: 0.2633 - accuracy: 0.8998 - precision_2: 0.8842 - recall_2: 0.5599 - f1_score: 0.6856 - val_loss: 0.4221 - val_accuracy: 0.8509 - val_precision_2: 0.7907 - val_recall_2: 0.3208 - val_f1_score: 0.4564 - 37s/epoch - 3s/step
# Epoch 47/200
# 11/11 - 37s - loss: 0.2561 - accuracy: 0.9004 - precision_2: 0.8792 - recall_2: 0.5680 - f1_score: 0.6901 - val_loss: 0.4198 - val_accuracy: 0.8491 - val_precision_2: 0.7727 - val_recall_2: 0.3208 - val_f1_score: 0.4533 - 37s/epoch - 3s/step
# Epoch 48/200
# 11/11 - 37s - loss: 0.2496 - accuracy: 0.9046 - precision_2: 0.8823 - recall_2: 0.5902 - f1_score: 0.7073 - val_loss: 0.4250 - val_accuracy: 0.8485 - val_precision_2: 0.7669 - val_recall_2: 0.3208 - val_f1_score: 0.4523 - 37s/epoch - 3s/step
# Epoch 49/200
# 11/11 - 37s - loss: 0.2427 - accuracy: 0.9084 - precision_2: 0.8918 - recall_2: 0.6043 - f1_score: 0.7204 - val_loss: 0.4340 - val_accuracy: 0.8491 - val_precision_2: 0.7647 - val_recall_2: 0.3270 - val_f1_score: 0.4581 - 37s/epoch - 3s/step
# Epoch 50/200
# 11/11 - 37s - loss: 0.2347 - accuracy: 0.9104 - precision_2: 0.8941 - recall_2: 0.6137 - f1_score: 0.7279 - val_loss: 0.4256 - val_accuracy: 0.8472 - val_precision_2: 0.7255 - val_recall_2: 0.3491 - val_f1_score: 0.4713 - 37s/epoch - 3s/step
# Epoch 51/200
# 11/11 - 37s - loss: 0.2252 - accuracy: 0.9172 - precision_2: 0.8978 - recall_2: 0.6501 - f1_score: 0.7541 - val_loss: 0.4328 - val_accuracy: 0.8491 - val_precision_2: 0.7500 - val_recall_2: 0.3396 - val_f1_score: 0.4675 - 37s/epoch - 3s/step
# Epoch 52/200
# 11/11 - 37s - loss: 0.2189 - accuracy: 0.9190 - precision_2: 0.9019 - recall_2: 0.6561 - f1_score: 0.7596 - val_loss: 0.4350 - val_accuracy: 0.8521 - val_precision_2: 0.7655 - val_recall_2: 0.3491 - val_f1_score: 0.4795 - 37s/epoch - 3s/step
# Epoch 53/200
# 11/11 - 37s - loss: 0.2099 - accuracy: 0.9239 - precision_2: 0.9060 - recall_2: 0.6810 - f1_score: 0.7776 - val_loss: 0.4409 - val_accuracy: 0.8528 - val_precision_2: 0.7671 - val_recall_2: 0.3522 - val_f1_score: 0.4828 - 37s/epoch - 3s/step
# Epoch 54/200
# 11/11 - 37s - loss: 0.2008 - accuracy: 0.9289 - precision_2: 0.9127 - recall_2: 0.7032 - f1_score: 0.7944 - val_loss: 0.4399 - val_accuracy: 0.8540 - val_precision_2: 0.7564 - val_recall_2: 0.3711 - val_f1_score: 0.4979 - 37s/epoch - 3s/step
# Epoch 55/200
# 11/11 - 37s - loss: 0.1926 - accuracy: 0.9313 - precision_2: 0.9147 - recall_2: 0.7147 - f1_score: 0.8024 - val_loss: 0.4486 - val_accuracy: 0.8503 - val_precision_2: 0.7312 - val_recall_2: 0.3679 - val_f1_score: 0.4895 - 37s/epoch - 3s/step
# Epoch 56/200
# 11/11 - 37s - loss: 0.1841 - accuracy: 0.9352 - precision_2: 0.9204 - recall_2: 0.7315 - f1_score: 0.8151 - val_loss: 0.4489 - val_accuracy: 0.8515 - val_precision_2: 0.7375 - val_recall_2: 0.3711 - val_f1_score: 0.4937 - 37s/epoch - 3s/step
# Epoch 57/200
# 11/11 - 37s - loss: 0.1751 - accuracy: 0.9383 - precision_2: 0.9212 - recall_2: 0.7476 - f1_score: 0.8254 - val_loss: 0.4550 - val_accuracy: 0.8509 - val_precision_2: 0.7273 - val_recall_2: 0.3774 - val_f1_score: 0.4969 - 37s/epoch - 3s/step
# Epoch 58/200
# 11/11 - 37s - loss: 0.1667 - accuracy: 0.9422 - precision_2: 0.9280 - recall_2: 0.7631 - f1_score: 0.8375 - val_loss: 0.4562 - val_accuracy: 0.8503 - val_precision_2: 0.7151 - val_recall_2: 0.3868 - val_f1_score: 0.5020 - 37s/epoch - 3s/step
# Epoch 59/200
# 11/11 - 37s - loss: 0.1574 - accuracy: 0.9463 - precision_2: 0.9325 - recall_2: 0.7813 - f1_score: 0.8502 - val_loss: 0.4666 - val_accuracy: 0.8528 - val_precision_2: 0.7294 - val_recall_2: 0.3899 - val_f1_score: 0.5082 - 37s/epoch - 3s/step
# Epoch 60/200
# ...
# Epoch 103/200
# 11/11 - 36s - loss: 0.0347 - accuracy: 0.9907 - precision_2: 0.9803 - recall_2: 0.9717 - f1_score: 0.9760 - val_loss: 0.7370 - val_accuracy: 0.8374 - val_precision_2: 0.6064 - val_recall_2: 0.4748 - val_f1_score: 0.5326 - 36s/epoch - 3s/step
# Epoch 104/200
# 11/11 - 36s - loss: 0.0427 - accuracy: 0.9870 - precision_2: 0.9639 - recall_2: 0.9697 - f1_score: 0.9668 - val_loss: 0.7266 - val_accuracy: 0.8466 - val_precision_2: 0.6518 - val_recall_2: 0.4591 - val_f1_score: 0.5387 - 36s/epoch - 3s/step
# Epoch 105/200
# 11/11 - 36s - loss: 0.0523 - accuracy: 0.9823 - precision_2: 0.9586 - recall_2: 0.9502 - f1_score: 0.9544 - val_loss: 0.7188 - val_accuracy: 0.8294 - val_precision_2: 0.5735 - val_recall_2: 0.4906 - val_f1_score: 0.5288 - 36s/epoch - 3s/step
# Epoch 106/200
# 11/11 - 36s - loss: 0.0597 - accuracy: 0.9781 - precision_2: 0.9471 - recall_2: 0.9401 - f1_score: 0.9436 - val_loss: 0.7330 - val_accuracy: 0.8411 - val_precision_2: 0.6255 - val_recall_2: 0.4623 - val_f1_score: 0.5316 - 36s/epoch - 3s/step
# Epoch 107/200
# 11/11 - 36s - loss: 0.0554 - accuracy: 0.9820 - precision_2: 0.9610 - recall_2: 0.9462 - f1_score: 0.9535 - val_loss: 0.7455 - val_accuracy: 0.8521 - val_precision_2: 0.6897 - val_recall_2: 0.4403 - val_f1_score: 0.5374 - 36s/epoch - 3s/step
# Epoch 108/200
# 11/11 - 36s - loss: 0.0352 - accuracy: 0.9917 - precision_2: 0.9830 - recall_2: 0.9744 - f1_score: 0.9787 - val_loss: 0.7249 - val_accuracy: 0.7969 - val_precision_2: 0.4826 - val_recall_2: 0.5660 - val_f1_score: 0.5210 - 36s/epoch - 3s/step
# Epoch 109/200
# 11/11 - 36s - loss: 0.0566 - accuracy: 0.9775 - precision_2: 0.9446 - recall_2: 0.9401 - f1_score: 0.9423 - val_loss: 0.7647 - val_accuracy: 0.7853 - val_precision_2: 0.4617 - val_recall_2: 0.6069 - val_f1_score: 0.5245 - 36s/epoch - 3s/step
# Epoch 110/200
# 11/11 - 36s - loss: 0.0801 - accuracy: 0.9653 - precision_2: 0.9371 - recall_2: 0.8816 - f1_score: 0.9085 - val_loss: 0.8962 - val_accuracy: 0.7092 - val_precision_2: 0.3687 - val_recall_2: 0.6887 - val_f1_score: 0.4803 - 36s/epoch - 3s/step
# Epoch 111/200
# 11/11 - 36s - loss: 0.1026 - accuracy: 0.9586 - precision_2: 0.8932 - recall_2: 0.8950 - f1_score: 0.8941 - val_loss: 0.6946 - val_accuracy: 0.8129 - val_precision_2: 0.5192 - val_recall_2: 0.5535 - val_f1_score: 0.5358 - 36s/epoch - 3s/step
# Epoch 112/200
# 11/11 - 36s - loss: 0.0600 - accuracy: 0.9816 - precision_2: 0.9591 - recall_2: 0.9462 - f1_score: 0.9526 - val_loss: 0.7147 - val_accuracy: 0.8092 - val_precision_2: 0.5097 - val_recall_2: 0.5786 - val_f1_score: 0.5420 - 36s/epoch - 3s/step
# Epoch 113/200
# 11/11 - 36s - loss: 0.0609 - accuracy: 0.9753 - precision_2: 0.9629 - recall_2: 0.9085 - f1_score: 0.9349 - val_loss: 0.8897 - val_accuracy: 0.7221 - val_precision_2: 0.3818 - val_recall_2: 0.6855 - val_f1_score: 0.4904 - 36s/epoch - 3s/step
# Epoch 114/200
# 11/11 - 36s - loss: 0.1124 - accuracy: 0.9511 - precision_2: 0.8917 - recall_2: 0.8533 - f1_score: 0.8721 - val_loss: 0.8553 - val_accuracy: 0.7074 - val_precision_2: 0.3627 - val_recall_2: 0.6604 - val_f1_score: 0.4682 - 36s/epoch - 3s/step
# Epoch 115/200
# 11/11 - 36s - loss: 0.1311 - accuracy: 0.9448 - precision_2: 0.8601 - recall_2: 0.8567 - f1_score: 0.8584 - val_loss: 0.7110 - val_accuracy: 0.8086 - val_precision_2: 0.5088 - val_recall_2: 0.5440 - val_f1_score: 0.5258 - 36s/epoch - 3s/step
# Epoch 116/200
# 11/11 - 36s - loss: 0.0920 - accuracy: 0.9606 - precision_2: 0.9051 - recall_2: 0.8917 - f1_score: 0.8983 - val_loss: 0.7004 - val_accuracy: 0.8129 - val_precision_2: 0.5213 - val_recall_2: 0.5000 - val_f1_score: 0.5104 - 36s/epoch - 3s/step
# Epoch 117/200
# 11/11 - 36s - loss: 0.0638 - accuracy: 0.9787 - precision_2: 0.9425 - recall_2: 0.9489 - f1_score: 0.9457 - val_loss: 0.6954 - val_accuracy: 0.8301 - val_precision_2: 0.5804 - val_recall_2: 0.4654 - val_f1_score: 0.5166 - 36s/epoch - 3s/step
# Epoch 118/200
# 11/11 - 36s - loss: 0.0395 - accuracy: 0.9892 - precision_2: 0.9718 - recall_2: 0.9731 - f1_score: 0.9724 - val_loss: 0.7376 - val_accuracy: 0.8313 - val_precision_2: 0.5863 - val_recall_2: 0.4591 - val_f1_score: 0.5150 - 36s/epoch - 3s/step
# Epoch 119/200
# 11/11 - 36s - loss: 0.0274 - accuracy: 0.9950 - precision_2: 0.9872 - recall_2: 0.9872 - f1_score: 0.9872 - val_loss: 0.7411 - val_accuracy: 0.8288 - val_precision_2: 0.5753 - val_recall_2: 0.4686 - val_f1_score: 0.5165 - 36s/epoch - 3s/step
# Epoch 120/200
# 11/11 - 36s - loss: 0.0218 - accuracy: 0.9966 - precision_2: 0.9886 - recall_2: 0.9939 - f1_score: 0.9913 - val_loss: 0.7565 - val_accuracy: 0.8319 - val_precision_2: 0.5833 - val_recall_2: 0.4843 - val_f1_score: 0.5292 - 36s/epoch - 3s/step
# Epoch 121/200
# 11/11 - 36s - loss: 0.0187 - accuracy: 0.9974 - precision_2: 0.9880 - recall_2: 0.9987 - f1_score: 0.9933 - val_loss: 0.7643 - val_accuracy: 0.8319 - val_precision_2: 0.5833 - val_recall_2: 0.4843 - val_f1_score: 0.5292 - 36s/epoch - 3s/step
# Epoch 122/200
# 11/11 - 36s - loss: 0.0170 - accuracy: 0.9974 - precision_2: 0.9880 - recall_2: 0.9987 - f1_score: 0.9933 - val_loss: 0.7735 - val_accuracy: 0.8350 - val_precision_2: 0.5961 - val_recall_2: 0.4780 - val_f1_score: 0.5305 - 36s/epoch - 3s/step
# Epoch 123/200
# 11/11 - 36s - loss: 0.0150 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.7843 - val_accuracy: 0.8380 - val_precision_2: 0.6080 - val_recall_2: 0.4780 - val_f1_score: 0.5352 - 36s/epoch - 3s/step
# Epoch 124/200
# 11/11 - 36s - loss: 0.0136 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.7886 - val_accuracy: 0.8368 - val_precision_2: 0.6008 - val_recall_2: 0.4874 - val_f1_score: 0.5382 - 36s/epoch - 3s/step
# Epoch 125/200
# 11/11 - 36s - loss: 0.0129 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.7926 - val_accuracy: 0.8344 - val_precision_2: 0.5916 - val_recall_2: 0.4874 - val_f1_score: 0.5345 - 36s/epoch - 3s/step
# Epoch 126/200
# 11/11 - 36s - loss: 0.0124 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.7981 - val_accuracy: 0.8356 - val_precision_2: 0.5962 - val_recall_2: 0.4874 - val_f1_score: 0.5363 - 36s/epoch - 3s/step
# Epoch 127/200
# 11/11 - 36s - loss: 0.0118 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.8037 - val_accuracy: 0.8374 - val_precision_2: 0.6031 - val_recall_2: 0.4874 - val_f1_score: 0.5391 - 36s/epoch - 3s/step
# Epoch 128/200
# 11/11 - 36s - loss: 0.0113 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.8082 - val_accuracy: 0.8368 - val_precision_2: 0.6008 - val_recall_2: 0.4874 - val_f1_score: 0.5382 - 36s/epoch - 3s/step
# Epoch 129/200
# 11/11 - 36s - loss: 0.0109 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.8130 - val_accuracy: 0.8374 - val_precision_2: 0.6031 - val_recall_2: 0.4874 - val_f1_score: 0.5391 - 36s/epoch - 3s/step
# Epoch 130/200
# 11/11 - 36s - loss: 0.0106 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.8182 - val_accuracy: 0.8380 - val_precision_2: 0.6055 - val_recall_2: 0.4874 - val_f1_score: 0.5401 - 36s/epoch - 3s/step
# Epoch 131/200
# 11/11 - 36s - loss: 0.0102 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.8226 - val_accuracy: 0.8374 - val_precision_2: 0.6031 - val_recall_2: 0.4874 - val_f1_score: 0.5391 - 36s/epoch - 3s/step
# Epoch 132/200
# 11/11 - 36s - loss: 0.0099 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.8264 - val_accuracy: 0.8374 - val_precision_2: 0.6031 - val_recall_2: 0.4874 - val_f1_score: 0.5391 - 36s/epoch - 3s/step
# Epoch 133/200
# 11/11 - 36s - loss: 0.0096 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.8303 - val_accuracy: 0.8380 - val_precision_2: 0.6055 - val_recall_2: 0.4874 - val_f1_score: 0.5401 - 36s/epoch - 3s/step
# Epoch 134/200
# 11/11 - 36s - loss: 0.0094 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.8340 - val_accuracy: 0.8380 - val_precision_2: 0.6055 - val_recall_2: 0.4874 - val_f1_score: 0.5401 - 36s/epoch - 3s/step
# Epoch 135/200
# 11/11 - 36s - loss: 0.0091 - accuracy: 0.9976 - precision_2: 0.9880 - recall_2: 1.0000 - f1_score: 0.9940 - val_loss: 0.8377 - val_accuracy: 0.8399 - val_precision_2: 0.6118 - val_recall_2: 0.4906 - val_f1_score: 0.5445 - 36s/epoch - 3s/step
# Epoch 136/200
# 11/11 - 36s - loss: 0.0089 - accuracy: 0.9975 - precision_2: 0.9880 - recall_2: 0.9993 - f1_score: 0.9936 - val_loss: 0.8413 - val_accuracy: 0.8399 - val_precision_2: 0.6118 - val_recall_2: 0.4906 - val_f1_score: 0.5445 - 36s/epoch - 3s/step
# INFO:tensorflow:Assets written to: model/model/assets
# INFO:tensorflow:Assets written to: model/model/assets
# Evaluate the model
# 2024-11-20 10:25:40.258750: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 59 of 1633
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (104170200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 10:25:53.370407: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 83 of 1633
# 2024-11-20 10:26:00.501677: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 121 of 1633
# 2024-11-20 10:26:10.498590: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 186 of 1633
# 2024-11-20 10:26:20.920356: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 215 of 1633
# 2024-11-20 10:26:30.751963: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 288 of 1633
# 2024-11-20 10:26:40.162276: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 350 of 1633
# 2024-11-20 10:26:50.309502: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 406 of 1633
# 2024-11-20 10:26:59.943649: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 464 of 1633
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (157946284 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 10:27:14.439371: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 491 of 1633
# 2024-11-20 10:27:20.587082: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 531 of 1633
# 2024-11-20 10:27:31.128403: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 576 of 1633
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (105654236 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 10:27:40.546661: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 611 of 1633
# 2024-11-20 10:27:51.302094: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 673 of 1633
# 2024-11-20 10:28:00.544825: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 702 of 1633
# 2024-11-20 10:28:11.693075: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 763 of 1633
# 2024-11-20 10:28:20.483209: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 833 of 1633
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (99405496 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 10:28:31.737141: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 887 of 1633
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (98011704 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 10:28:40.195454: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 925 of 1633
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (95695936 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 10:28:50.728982: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 967 of 1633
# 2024-11-20 10:29:00.374430: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1026 of 1633
# 2024-11-20 10:29:11.920636: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1077 of 1633
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (123732464 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 10:29:21.062022: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1097 of 1633
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (159665208 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 10:29:33.214583: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1140 of 1633
# /home/users/mbenali/.conda/envs/dexray/lib/python3.10/site-packages/PIL/Image.py:3406: DecompressionBombWarning: Image size (134464252 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2024-11-20 10:29:45.628884: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1176 of 1633
# 2024-11-20 10:29:50.491948: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1201 of 1633
# 2024-11-20 10:30:02.160780: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1233 of 1633
# 2024-11-20 10:30:10.513606: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1295 of 1633
# 2024-11-20 10:30:22.490278: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1363 of 1633
# 2024-11-20 10:30:29.998661: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1423 of 1633
# 2024-11-20 10:30:39.946946: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1498 of 1633
# 2024-11-20 10:30:50.627284: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 1561 of 1633
# 2024-11-20 10:30:58.650906: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] Shuffle buffer filled.
# 11/11 - 331s - loss: 0.7212 - accuracy: 0.8592 - precision_2: 0.7730 - recall_2: 0.3950 - f1_score: 0.5228 - 331s/epoch - 30s/step

# %%
from tensorflow.keras.models import load_model

# Load the model
loaded_model = load_model('model/model')
